# %%
import xarray as xr

db=xr.open_dataset('/home/CHIRPSSPIHIGHRES1981to2022.nc')

db
# Out:
# /opt/conda/lib/python3.9/site-packages/xarray/coding/times.py:527: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/conda/lib/python3.9/site-packages/xarray/core/indexing.py:419: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(array[self.key], dtype=None)
# <xarray.Dataset>
# Dimensions:    (time: 504, latitude: 770, longitude: 640)
# Coordinates:
#   * time       (time) object 2522-05-20 00:00:00 ... 2533-08-21 00:00:00
#   * latitude   (latitude) float32 -13.48 -13.42 -13.38 ... 24.88 24.92 24.97
#   * longitude  (longitude) float32 20.02 20.07 20.12 20.18 ... 51.88 51.93 51.97
# Data variables:
#     month4SPI  (time, latitude, longitude) float64 ...
#     month3SPI  (time, latitude, longitude) float64 ...
#     month7SPI  (time, latitude, longitude) float64 ...
#     month9SPI  (time, latitude, longitude) float64 ...
# Attributes:
#     creation_date:  Mon Feb 27 20:11:19 EAT 2023
#     title:          CHIRPSSPIHIGHRES1981to2022

# %%
db['time']
# Out:
# <xarray.DataArray 'time' (time: 504)>
# array([cftime.DatetimeGregorian(2522, 5, 20, 0, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(2522, 5, 21, 0, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(2522, 5, 22, 0, 0, 0, 0, has_year_zero=False),
#        ...,
#        cftime.DatetimeGregorian(2533, 8, 19, 0, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(2533, 8, 20, 0, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(2533, 8, 21, 0, 0, 0, 0, has_year_zero=False)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 2522-05-20 00:00:00 ... 2533-08-21 00:00:00
# Attributes:
#     standard_name:  time
#     axis:           T

# %%
(2022-1981)*12
# Out:
# 492

# %%
datetimeindex = db.indexes['time'].to_datetimeindex()
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/xarray/coding/times.py in cftime_to_nptime(times)
#     388             # datetime.datetime).
# --> 389             dt = pd.Timestamp(
#     390                 t.year, t.month, t.day, t.hour, t.minute, t.second, t.microsecond
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 2522-05-20 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_24867/1647934406.py in <module>
# ----> 1 datetimeindex = db.indexes['time'].to_datetimeindex()
#
# /opt/conda/lib/python3.9/site-packages/xarray/coding/cftimeindex.py in to_datetimeindex(self, unsafe)
#     630         DatetimeIndex(['2000-01-01', '2000-01-02'], dtype='datetime64[ns]', freq=None)
#     631         """
# --> 632         nptimes = cftime_to_nptime(self)
#     633         calendar = infer_calendar_name(self)
#     634         if calendar not in _STANDARD_CALENDARS and not unsafe:
#
# /opt/conda/lib/python3.9/site-packages/xarray/coding/times.py in cftime_to_nptime(times)
#     391             )
#     392         except ValueError as e:
# --> 393             raise ValueError(
#     394                 "Cannot convert date {} to a date in the "
#     395                 "standard calendar.  Reason: {}.".format(t, e)
#
# ValueError: Cannot convert date 2522-05-20 00:00:00 to a date in the standard calendar.  Reason: Out of bounds nanosecond timestamp: 2522-05-20 00:00:00.

# %%
db['month4SPI']
# Out:
# <xarray.DataArray 'month4SPI' (time: 504, latitude: 770, longitude: 640)>
# [248371200 values with dtype=float64]
# Coordinates:
#   * time       (time) object 2522-05-20 00:00:00 ... 2533-08-21 00:00:00
#   * latitude   (latitude) float32 -13.48 -13.42 -13.38 ... 24.88 24.92 24.97
#   * longitude  (longitude) float32 20.02 20.07 20.12 20.18 ... 51.88 51.93 51.97

# %% [markdown]
# ## read CPT txt file
#
# Based on https://iri-pycpt.github.io/

# %%
import re
f = open('/home/ECMWF_OND_Uganda_SPIReforecast/ECMWF_OND1981_Uganda_SPI-0.03_0.59.txt','r')

LIST = []
LIST1 = []
for line in f:
    if re.search('[0-9]{4}', line)!= None:
        line= line.strip('\n')
        tokens = line.split('\t')
        LIST.append(tokens)
    if re.search('[ \t]',line) != None:
        line= line.strip('\n')
        tokens = line.split('\t')
        LIST1.append(tokens)

# %%
LIST1
# Out:
# [['cpt:field=precipitation, cpt:C=1, cpt:clim_prob=0.320000000000, cpt:T=1981-10/12, cpt:nrow=14, cpt:ncol=12, cpt:row=Y, cpt:col=X, cpt:units=probability (%), cpt:missing=-1.00000000000                   '],
#  ['',
#   '29.25',
#   '29.75',
#   '30.25',
#   '30.75',
#   '31.25',
#   '31.75',
#   '32.25',
#   '32.75',
#   '33.25',
#   '33.75',
#   '34.25',
#   '34.75'],
#  ['4.75',
#   '32.2205769064',
#   '40.1096915412',
#   '38.3697903916',
#   '37.4739670689',
#   '33.7962587746',
#   '36.6610238159',
#   '31.1560450492',
#   '36.9894945564',
#   '37.6403299194',
#   '36.2555046349',
#   '40.8274897771',
#   '46.5953647135'],
#  ['4.25',
#   '37.3548799487',
#   '38.2777716184',
#   '37.5852806575',
#   '36.2753238976',
#   '31.9973564146',
#   '38.4308996303',
#   '36.7737100971',
#   '40.5965782706',
#   '40.0248159064',
#   '34.5575444940',
#   '38.3000802626',
#   '41.8851811901'],
#  ['3.75',
#   '36.5162113515',
#   '35.9845604736',
#   '37.4089203247',
#   '38.6860461594',
#   '39.1086849318',
#   '40.1809721856',
#   '43.2562518662',
#   '37.1118403222',
#   '40.5790419215',
#   '40.4222569456',
#   '41.6119326781',
#   '43.5787462838'],
#  ['3.25',
#   '37.9416760570',
#   '37.4855307546',
#   '40.6146738822',
#   '35.8449218658',
#   '35.4386137283',
#   '45.7519577413',
#   '48.3851273555',
#   '40.4367407361',
#   '41.7400687135',
#   '41.3964019185',
#   '41.1772148812',
#   '42.3572402737'],
#  ['2.75',
#   '36.6437471673',
#   '38.1404655023',
#   '37.8030999785',
#   '38.2927616784',
#   '39.0413921776',
#   '46.4542286740',
#   '49.5076296057',
#   '38.1625262446',
#   '34.8982862646',
#   '30.1666909826',
#   '42.2044411252',
#   '40.9648721658'],
#  ['2.25',
#   '40.9288775411',
#   '39.3326763619',
#   '42.4177998209',
#   '49.1377621527',
#   '45.0231839323',
#   '47.4162334383',
#   '48.4223498358',
#   '43.0078997261',
#   '42.4263259993',
#   '40.9566978741',
#   '41.5385536068',
#   '37.9970053906'],
#  ['1.75',
#   '34.6024867442',
#   '33.3508275919',
#   '41.8984856143',
#   '42.5870934453',
#   '41.9726817704',
#   '38.6540862452',
#   '41.7577125216',
#   '48.4602547012',
#   '39.8066423650',
#   '41.8312007442',
#   '38.2779694351',
#   '43.0857350142'],
#  ['1.25',
#   '36.3275932357',
#   '39.3423620412',
#   '38.7468320520',
#   '32.0802709767',
#   '36.4705873889',
#   '33.1831652378',
#   '38.5453681100',
#   '36.8989962042',
#   '38.4872389760',
#   '48.4012449681',
#   '36.5134779005',
#   '38.2045104593'],
#  ['0.75',
#   '29.7469951722',
#   '34.4830974444',
#   '31.8199810943',
#   '37.0820846308',
#   '31.2274259893',
#   '43.3891633096',
#   '45.5294783136',
#   '41.3439241219',
#   '39.1305345538',
#   '39.8215127635',
#   '35.0816767320',
#   '45.3419078825'],
#  ['0.25',
#   '36.4797704689',
#   '35.8686263520',
#   '28.3231985850',
#   '31.8981977898',
#   '39.1075856163',
#   '34.0203042288',
#   '42.0489188002',
#   '36.0519854653',
#   '34.6643072052',
#   '39.6621313663',
#   '27.6867828206',
#   '40.8628915648'],
#  ['-0.25',
#   '34.0931296315',
#   '42.0082035227',
#   '35.2234317419',
#   '35.6357931246',
#   '38.8680597744',
#   '26.5620448011',
#   '40.1270802078',
#   '43.1560638243',
#   '44.8318415823',
#   '39.2975246710',
#   '29.8187612087',
#   '33.9924796755'],
#  ['-0.75',
#   '36.8834802977',
#   '35.7705522756',
#   '44.3049981306',
#   '40.2725611495',
#   '39.9390096114',
#   '32.8815889222',
#   '36.4272436226',
#   '41.5679256061',
#   '41.7110865417',
#   '42.8871101282',
#   '33.9272788289',
#   '40.2518389859'],
#  ['-1.25',
#   '31.6412861291',
#   '42.5756901806',
#   '50.9988938542',
#   '35.1219675801',
#   '32.6097543283',
#   '39.0175816605',
#   '41.4022858583',
#   '39.7576350572',
#   '41.9687708217',
#   '41.4064240957',
#   '33.5649984988',
#   '32.5333427118'],
#  ['-1.75',
#   '33.5454503978',
#   '40.4704219139',
#   '37.9724381230',
#   '43.2613988335',
#   '36.3781893587',
#   '38.7471798970',
#   '34.6471682044',
#   '46.7357459604',
#   '44.2076252810',
#   '37.3867173803',
#   '34.6338605356',
#   '36.1685076458'],
#  ['cpt:C=2, cpt:clim_prob=1.000000000000E-02'],
#  ['',
#   '29.25',
#   '29.75',
#   '30.25',
#   '30.75',
#   '31.25',
#   '31.75',
#   '32.25',
#   '32.75',
#   '33.25',
#   '33.75',
#   '34.25',
#   '34.75'],
#  ['4.75',
#   '27.3156372120',
#   '21.0519328034',
#   '19.8180331744',
#   '11.3266643245',
#   '25.0010167334',
#   '22.5326584596',
#   '22.5479620872',
#   '15.1971380671',
#   '15.8111004807',
#   '19.8241262394',
#   '14.9225130003',
#   '21.6563419713'],
#  ['4.25',
#   '15.6187995358',
#   '16.6225732297',
#   '14.7168488202',
#   '20.6328564268',
#   '27.0555755314',
#   '19.0310152773',
#   '19.9147109427',
#   '9.61407665790',
#   '7.66337480256',
#   '22.6698033505',
#   '27.1631039438',
#   '30.3082879356'],
#  ['3.75',
#   '18.1670721232',
#   '12.9610143185',
#   '12.5662771738',
#   '16.8107474763',
#   '23.1132553951',
#   '20.7758851643',
#   '18.1297656676',
#   '15.8620492968',
#   '13.0299950546',
#   '19.3938034578',
#   '18.8981230997',
#   '24.5364663626'],
#  ['3.25',
#   '12.9263861423',
#   '13.6445633914',
#   '8.03351949088',
#   '22.6002844056',
#   '24.6666533149',
#   '10.1374627752',
#   '10.7449849989',
#   '24.4365795967',
#   '16.6067621825',
#   '20.1710874643',
#   '23.7816565781',
#   '27.7230506764'],
#  ['2.75',
#   '13.0492417838',
#   '14.7070233152',
#   '19.6117262758',
#   '19.9704355346',
#   '24.7442123490',
#   '12.7981474780',
#   '11.2209303995',
#   '25.7398829876',
#   '27.9266324905',
#   '31.4536469155',
#   '16.2537374870',
#   '25.6617242586'],
#  ['2.25',
#   '6.74611334508',
#   '12.2436628188',
#   '12.5697570981',
#   '11.1642359158',
#   '14.7155338363',
#   '16.0649429999',
#   '15.5335375371',
#   '18.2768424892',
#   '23.7684708036',
#   '17.7310603702',
#   '9.89619124960',
#   '29.6990826055'],
#  ['1.75',
#   '16.2158140472',
#   '23.4597596031',
#   '14.6584054917',
#   '18.2535447686',
#   '13.7732712910',
#   '19.7971595485',
#   '21.5130093377',
#   '14.1877391192',
#   '26.3048777697',
#   '23.5829139319',
#   '17.3729895058',
#   '11.2927467048'],
#  ['1.25',
#   '21.4577507824',
#   '19.8163142034',
#   '23.0894881548',
#   '25.8739152081',
#   '16.3205238704',
#   '30.4375883072',
#   '26.4810303794',
#   '27.1572324930',
#   '17.8718763697',
#   '15.1038349328',
#   '25.1677501548',
#   '19.3400974594'],
#  ['0.75',
#   '30.1255496750',
#   '19.2125073856',
#   '15.6992486582',
#   '13.0885959908',
#   '19.6850634330',
#   '12.6568846504',
#   '13.8860326740',
#   '17.4693568918',
#   '22.9361028448',
#   '25.9638659572',
#   '26.7098259960',
#   '14.5567099686'],
#  ['0.25',
#   '20.4668167126',
#   '19.4391346522',
#   '28.9357041855',
#   '21.6685339249',
#   '12.5380721402',
#   '25.1567591801',
#   '15.8470831309',
#   '28.3399835376',
#   '32.6065321719',
#   '29.7102313393',
#   '39.3595163912',
#   '18.4702940327'],
#  ['-0.25',
#   '20.2330116987',
#   '14.3293204196',
#   '22.5629496415',
#   '24.3602400467',
#   '20.3542701358',
#   '41.4273321839',
#   '25.5968750756',
#   '24.2321494644',
#   '15.6439773982',
#   '19.3040533003',
#   '37.8580302305',
#   '30.7714904638'],
#  ['-0.75',
#   '15.9178486653',
#   '22.9321879198',
#   '10.5723708907',
#   '21.9303652673',
#   '21.3592364491',
#   '28.0729536418',
#   '26.4979077708',
#   '32.5079635894',
#   '21.2241431202',
#   '18.3424238540',
#   '28.9015254842',
#   '20.6445761673'],
#  ['-1.25',
#   '18.5415260976',
#   '17.4435115952',
#   '10.5824898967',
#   '32.5443650545',
#   '30.8248928199',
#   '22.2446915817',
#   '25.0260720488',
#   '27.1191799605',
#   '22.1629841636',
#   '19.2552829156',
#   '28.7726770862',
#   '36.5171982854'],
#  ['-1.75',
#   '21.5629331038',
#   '19.0755483430',
#   '27.0484825151',
#   '17.9580466863',
#   '26.9695839478',
#   '19.5467813553',
#   '33.4308935453',
#   '10.3293943816',
#   '17.4436052633',
#   '23.8977901857',
#   '24.0927460145',
#   '22.3518988612'],
#  ['cpt:C=3, cpt:clim_prob=0.670000000000'],
#  ['',
#   '29.25',
#   '29.75',
#   '30.25',
#   '30.75',
#   '31.25',
#   '31.75',
#   '32.25',
#   '32.75',
#   '33.25',
#   '33.75',
#   '34.25',
#   '34.75'],
#  ['4.75',
#   '40.4637858816',
#   '38.8383756554',
#   '41.8121764339',
#   '51.1993686065',
#   '41.2027244919',
#   '40.8063177245',
#   '46.2959928636',
#   '47.8133673765',
#   '46.5485695999',
#   '43.9203691257',
#   '44.2499972226',
#   '31.7482933152'],
#  ['4.25',
#   '47.0263205155',
#   '45.0996551519',
#   '47.6978705223',
#   '43.0918196756',
#   '40.9470680541',
#   '42.5380850924',
#   '43.3115789602',
#   '49.7893450715',
#   '52.3118092910',
#   '42.7726521554',
#   '34.5368157936',
#   '27.8065308743'],
#  ['3.75',
#   '45.3167165253',
#   '51.0544252078',
#   '50.0248025015',
#   '44.5032063643',
#   '37.7780596731',
#   '39.0431426500',
#   '38.6139824662',
#   '47.0261103810',
#   '46.3909630238',
#   '40.1839395967',
#   '39.4899442223',
#   '31.8847873536'],
#  ['3.25',
#   '49.1319378007',
#   '48.8699058541',
#   '51.3518066269',
#   '41.5547937287',
#   '39.8947329568',
#   '44.1105794834',
#   '40.8698876456',
#   '35.1266796672',
#   '41.6531691040',
#   '38.4325106172',
#   '35.0411285408',
#   '29.9197090499'],
#  ['2.75',
#   '50.3070110489',
#   '47.1525111825',
#   '42.5851737457',
#   '41.7368027870',
#   '36.2143954734',
#   '40.7476238480',
#   '39.2714399947',
#   '36.0975907677',
#   '37.1750812448',
#   '38.3796621019',
#   '41.5418213878',
#   '33.3734035756'],
#  ['2.25',
#   '52.3250091139',
#   '48.4236608193',
#   '45.0124430810',
#   '39.6980019314',
#   '40.2612822313',
#   '36.5188235618',
#   '36.0441126271',
#   '38.7152577847',
#   '33.8052031971',
#   '41.3122417557',
#   '48.5652551436',
#   '32.3039120039'],
#  ['1.75',
#   '49.1816992086',
#   '43.1894128050',
#   '43.4431088940',
#   '39.1593617860',
#   '44.2540469386',
#   '41.5487542063',
#   '36.7292781408',
#   '37.3520061796',
#   '33.8884798654',
#   '34.5858853239',
#   '44.3490410592',
#   '45.6215182810'],
#  ['1.25',
#   '42.2146559819',
#   '40.8413237553',
#   '38.1636797932',
#   '42.0458138152',
#   '47.2088887407',
#   '36.3792464550',
#   '34.9736015106',
#   '35.9437713028',
#   '43.6408846543',
#   '36.4949200992',
#   '38.3187719448',
#   '42.4553920812'],
#  ['0.75',
#   '40.1274551528',
#   '46.3043951701',
#   '52.4807702475',
#   '49.8293193784',
#   '49.0875105777',
#   '43.9539520400',
#   '40.5844890124',
#   '41.1867189863',
#   '37.9333626014',
#   '34.2146212793',
#   '38.2084972720',
#   '40.1013821489'],
#  ['0.25',
#   '43.0534128186',
#   '44.6922389958',
#   '42.7410972295',
#   '46.4332682852',
#   '48.3543422435',
#   '40.8229365911',
#   '42.1039980689',
#   '35.6080309971',
#   '32.7291606229',
#   '30.6276372945',
#   '32.9537007882',
#   '40.6668144026'],
#  ['-0.25',
#   '45.6738586698',
#   '43.6624760577',
#   '42.2136186166',
#   '40.0039668287',
#   '40.7776700897',
#   '32.0106230150',
#   '34.2760447166',
#   '32.6117867112',
#   '39.5241810195',
#   '41.3984220287',
#   '32.3232085608',
#   '35.2360298608'],
#  ['-0.75',
#   '47.1986710370',
#   '41.2972598046',
#   '45.1226309787',
#   '37.7970735832',
#   '38.7017539396',
#   '39.0454574360',
#   '37.0748486067',
#   '25.9241108046',
#   '37.0647703381',
#   '38.7704660177',
#   '37.1711956869',
#   '39.1035848469'],
#  ['-1.25',
#   '49.8171877732',
#   '39.9807982242',
#   '38.4186162491',
#   '32.3336673654',
#   '36.5653528518',
#   '38.7377267578',
#   '33.5716420929',
#   '33.1231849823',
#   '35.8682450147',
#   '39.3382929887',
#   '37.6623244151',
#   '30.9494590027'],
#  ['-1.75',
#   '44.8916164984',
#   '40.4540297431',
#   '34.9790793619',
#   '38.7805544803',
#   '36.6522266935',
#   '41.7060387477',
#   '31.9219382503',
#   '42.9348596580',
#   '38.3487694557',
#   '38.7154924340',
#   '41.2733934499',
#   '41.4795934930']]

# %%
LIST = []

f = open('/home/ECMWF_OND_Uganda_SPIReforecast/ECMWF_OND1981_Uganda_SPI-0.03_0.59.txt','r')

for line in f:
    #print(line)
    print(re.search('[ \t]+',line))
# Out:
# None
# None
# <re.Match object; span=(24, 25), match=' '>
# <re.Match object; span=(0, 1), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(8, 9), match=' '>
# <re.Match object; span=(0, 1), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(8, 9), match=' '>
# <re.Match object; span=(0, 1), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(4, 5), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>
# <re.Match object; span=(5, 6), match='\t'>

# %%
idx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24867/3490336722.py in <module>
# ----> 1 idx
#
# NameError: name 'idx' is not defined

# %%
time=LIST[0][0].split(',')[3]
# Out:
# ' cpt:T=1981-10/12'

# %%
import numpy as np
time = np.array(LIST)[:,0].astype(dt)
time
# Out:
# /tmp/ipykernel_24867/3338608949.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   time = np.array(LIST)[:,0].astype(dt)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_24867/3338608949.py in <module>
#       1 import numpy as np
# ----> 2 time = np.array(LIST)[:,0].astype(dt)
#       3 time
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
LIST
# Out:
# [['cpt:field=precipitation, cpt:C=1, cpt:clim_prob=0.320000000000, cpt:T=1981-10/12, cpt:nrow=14, cpt:ncol=12, cpt:row=Y, cpt:col=X, cpt:units=probability (%), cpt:missing=-1.00000000000                   '],
#  ['4.75',
#   '32.2205769064',
#   '40.1096915412',
#   '38.3697903916',
#   '37.4739670689',
#   '33.7962587746',
#   '36.6610238159',
#   '31.1560450492',
#   '36.9894945564',
#   '37.6403299194',
#   '36.2555046349',
#   '40.8274897771',
#   '46.5953647135'],
#  ['4.25',
#   '37.3548799487',
#   '38.2777716184',
#   '37.5852806575',
#   '36.2753238976',
#   '31.9973564146',
#   '38.4308996303',
#   '36.7737100971',
#   '40.5965782706',
#   '40.0248159064',
#   '34.5575444940',
#   '38.3000802626',
#   '41.8851811901'],
#  ['3.75',
#   '36.5162113515',
#   '35.9845604736',
#   '37.4089203247',
#   '38.6860461594',
#   '39.1086849318',
#   '40.1809721856',
#   '43.2562518662',
#   '37.1118403222',
#   '40.5790419215',
#   '40.4222569456',
#   '41.6119326781',
#   '43.5787462838'],
#  ['3.25',
#   '37.9416760570',
#   '37.4855307546',
#   '40.6146738822',
#   '35.8449218658',
#   '35.4386137283',
#   '45.7519577413',
#   '48.3851273555',
#   '40.4367407361',
#   '41.7400687135',
#   '41.3964019185',
#   '41.1772148812',
#   '42.3572402737'],
#  ['2.75',
#   '36.6437471673',
#   '38.1404655023',
#   '37.8030999785',
#   '38.2927616784',
#   '39.0413921776',
#   '46.4542286740',
#   '49.5076296057',
#   '38.1625262446',
#   '34.8982862646',
#   '30.1666909826',
#   '42.2044411252',
#   '40.9648721658'],
#  ['2.25',
#   '40.9288775411',
#   '39.3326763619',
#   '42.4177998209',
#   '49.1377621527',
#   '45.0231839323',
#   '47.4162334383',
#   '48.4223498358',
#   '43.0078997261',
#   '42.4263259993',
#   '40.9566978741',
#   '41.5385536068',
#   '37.9970053906'],
#  ['1.75',
#   '34.6024867442',
#   '33.3508275919',
#   '41.8984856143',
#   '42.5870934453',
#   '41.9726817704',
#   '38.6540862452',
#   '41.7577125216',
#   '48.4602547012',
#   '39.8066423650',
#   '41.8312007442',
#   '38.2779694351',
#   '43.0857350142'],
#  ['1.25',
#   '36.3275932357',
#   '39.3423620412',
#   '38.7468320520',
#   '32.0802709767',
#   '36.4705873889',
#   '33.1831652378',
#   '38.5453681100',
#   '36.8989962042',
#   '38.4872389760',
#   '48.4012449681',
#   '36.5134779005',
#   '38.2045104593'],
#  ['0.75',
#   '29.7469951722',
#   '34.4830974444',
#   '31.8199810943',
#   '37.0820846308',
#   '31.2274259893',
#   '43.3891633096',
#   '45.5294783136',
#   '41.3439241219',
#   '39.1305345538',
#   '39.8215127635',
#   '35.0816767320',
#   '45.3419078825'],
#  ['0.25',
#   '36.4797704689',
#   '35.8686263520',
#   '28.3231985850',
#   '31.8981977898',
#   '39.1075856163',
#   '34.0203042288',
#   '42.0489188002',
#   '36.0519854653',
#   '34.6643072052',
#   '39.6621313663',
#   '27.6867828206',
#   '40.8628915648'],
#  ['-0.25',
#   '34.0931296315',
#   '42.0082035227',
#   '35.2234317419',
#   '35.6357931246',
#   '38.8680597744',
#   '26.5620448011',
#   '40.1270802078',
#   '43.1560638243',
#   '44.8318415823',
#   '39.2975246710',
#   '29.8187612087',
#   '33.9924796755'],
#  ['-0.75',
#   '36.8834802977',
#   '35.7705522756',
#   '44.3049981306',
#   '40.2725611495',
#   '39.9390096114',
#   '32.8815889222',
#   '36.4272436226',
#   '41.5679256061',
#   '41.7110865417',
#   '42.8871101282',
#   '33.9272788289',
#   '40.2518389859'],
#  ['-1.25',
#   '31.6412861291',
#   '42.5756901806',
#   '50.9988938542',
#   '35.1219675801',
#   '32.6097543283',
#   '39.0175816605',
#   '41.4022858583',
#   '39.7576350572',
#   '41.9687708217',
#   '41.4064240957',
#   '33.5649984988',
#   '32.5333427118'],
#  ['-1.75',
#   '33.5454503978',
#   '40.4704219139',
#   '37.9724381230',
#   '43.2613988335',
#   '36.3781893587',
#   '38.7471798970',
#   '34.6471682044',
#   '46.7357459604',
#   '44.2076252810',
#   '37.3867173803',
#   '34.6338605356',
#   '36.1685076458'],
#  ['cpt:C=2, cpt:clim_prob=1.000000000000E-02'],
#  ['4.75',
#   '27.3156372120',
#   '21.0519328034',
#   '19.8180331744',
#   '11.3266643245',
#   '25.0010167334',
#   '22.5326584596',
#   '22.5479620872',
#   '15.1971380671',
#   '15.8111004807',
#   '19.8241262394',
#   '14.9225130003',
#   '21.6563419713'],
#  ['4.25',
#   '15.6187995358',
#   '16.6225732297',
#   '14.7168488202',
#   '20.6328564268',
#   '27.0555755314',
#   '19.0310152773',
#   '19.9147109427',
#   '9.61407665790',
#   '7.66337480256',
#   '22.6698033505',
#   '27.1631039438',
#   '30.3082879356'],
#  ['3.75',
#   '18.1670721232',
#   '12.9610143185',
#   '12.5662771738',
#   '16.8107474763',
#   '23.1132553951',
#   '20.7758851643',
#   '18.1297656676',
#   '15.8620492968',
#   '13.0299950546',
#   '19.3938034578',
#   '18.8981230997',
#   '24.5364663626'],
#  ['3.25',
#   '12.9263861423',
#   '13.6445633914',
#   '8.03351949088',
#   '22.6002844056',
#   '24.6666533149',
#   '10.1374627752',
#   '10.7449849989',
#   '24.4365795967',
#   '16.6067621825',
#   '20.1710874643',
#   '23.7816565781',
#   '27.7230506764'],
#  ['2.75',
#   '13.0492417838',
#   '14.7070233152',
#   '19.6117262758',
#   '19.9704355346',
#   '24.7442123490',
#   '12.7981474780',
#   '11.2209303995',
#   '25.7398829876',
#   '27.9266324905',
#   '31.4536469155',
#   '16.2537374870',
#   '25.6617242586'],
#  ['2.25',
#   '6.74611334508',
#   '12.2436628188',
#   '12.5697570981',
#   '11.1642359158',
#   '14.7155338363',
#   '16.0649429999',
#   '15.5335375371',
#   '18.2768424892',
#   '23.7684708036',
#   '17.7310603702',
#   '9.89619124960',
#   '29.6990826055'],
#  ['1.75',
#   '16.2158140472',
#   '23.4597596031',
#   '14.6584054917',
#   '18.2535447686',
#   '13.7732712910',
#   '19.7971595485',
#   '21.5130093377',
#   '14.1877391192',
#   '26.3048777697',
#   '23.5829139319',
#   '17.3729895058',
#   '11.2927467048'],
#  ['1.25',
#   '21.4577507824',
#   '19.8163142034',
#   '23.0894881548',
#   '25.8739152081',
#   '16.3205238704',
#   '30.4375883072',
#   '26.4810303794',
#   '27.1572324930',
#   '17.8718763697',
#   '15.1038349328',
#   '25.1677501548',
#   '19.3400974594'],
#  ['0.75',
#   '30.1255496750',
#   '19.2125073856',
#   '15.6992486582',
#   '13.0885959908',
#   '19.6850634330',
#   '12.6568846504',
#   '13.8860326740',
#   '17.4693568918',
#   '22.9361028448',
#   '25.9638659572',
#   '26.7098259960',
#   '14.5567099686'],
#  ['0.25',
#   '20.4668167126',
#   '19.4391346522',
#   '28.9357041855',
#   '21.6685339249',
#   '12.5380721402',
#   '25.1567591801',
#   '15.8470831309',
#   '28.3399835376',
#   '32.6065321719',
#   '29.7102313393',
#   '39.3595163912',
#   '18.4702940327'],
#  ['-0.25',
#   '20.2330116987',
#   '14.3293204196',
#   '22.5629496415',
#   '24.3602400467',
#   '20.3542701358',
#   '41.4273321839',
#   '25.5968750756',
#   '24.2321494644',
#   '15.6439773982',
#   '19.3040533003',
#   '37.8580302305',
#   '30.7714904638'],
#  ['-0.75',
#   '15.9178486653',
#   '22.9321879198',
#   '10.5723708907',
#   '21.9303652673',
#   '21.3592364491',
#   '28.0729536418',
#   '26.4979077708',
#   '32.5079635894',
#   '21.2241431202',
#   '18.3424238540',
#   '28.9015254842',
#   '20.6445761673'],
#  ['-1.25',
#   '18.5415260976',
#   '17.4435115952',
#   '10.5824898967',
#   '32.5443650545',
#   '30.8248928199',
#   '22.2446915817',
#   '25.0260720488',
#   '27.1191799605',
#   '22.1629841636',
#   '19.2552829156',
#   '28.7726770862',
#   '36.5171982854'],
#  ['-1.75',
#   '21.5629331038',
#   '19.0755483430',
#   '27.0484825151',
#   '17.9580466863',
#   '26.9695839478',
#   '19.5467813553',
#   '33.4308935453',
#   '10.3293943816',
#   '17.4436052633',
#   '23.8977901857',
#   '24.0927460145',
#   '22.3518988612'],
#  ['cpt:C=3, cpt:clim_prob=0.670000000000'],
#  ['4.75',
#   '40.4637858816',
#   '38.8383756554',
#   '41.8121764339',
#   '51.1993686065',
#   '41.2027244919',
#   '40.8063177245',
#   '46.2959928636',
#   '47.8133673765',
#   '46.5485695999',
#   '43.9203691257',
#   '44.2499972226',
#   '31.7482933152'],
#  ['4.25',
#   '47.0263205155',
#   '45.0996551519',
#   '47.6978705223',
#   '43.0918196756',
#   '40.9470680541',
#   '42.5380850924',
#   '43.3115789602',
#   '49.7893450715',
#   '52.3118092910',
#   '42.7726521554',
#   '34.5368157936',
#   '27.8065308743'],
#  ['3.75',
#   '45.3167165253',
#   '51.0544252078',
#   '50.0248025015',
#   '44.5032063643',
#   '37.7780596731',
#   '39.0431426500',
#   '38.6139824662',
#   '47.0261103810',
#   '46.3909630238',
#   '40.1839395967',
#   '39.4899442223',
#   '31.8847873536'],
#  ['3.25',
#   '49.1319378007',
#   '48.8699058541',
#   '51.3518066269',
#   '41.5547937287',
#   '39.8947329568',
#   '44.1105794834',
#   '40.8698876456',
#   '35.1266796672',
#   '41.6531691040',
#   '38.4325106172',
#   '35.0411285408',
#   '29.9197090499'],
#  ['2.75',
#   '50.3070110489',
#   '47.1525111825',
#   '42.5851737457',
#   '41.7368027870',
#   '36.2143954734',
#   '40.7476238480',
#   '39.2714399947',
#   '36.0975907677',
#   '37.1750812448',
#   '38.3796621019',
#   '41.5418213878',
#   '33.3734035756'],
#  ['2.25',
#   '52.3250091139',
#   '48.4236608193',
#   '45.0124430810',
#   '39.6980019314',
#   '40.2612822313',
#   '36.5188235618',
#   '36.0441126271',
#   '38.7152577847',
#   '33.8052031971',
#   '41.3122417557',
#   '48.5652551436',
#   '32.3039120039'],
#  ['1.75',
#   '49.1816992086',
#   '43.1894128050',
#   '43.4431088940',
#   '39.1593617860',
#   '44.2540469386',
#   '41.5487542063',
#   '36.7292781408',
#   '37.3520061796',
#   '33.8884798654',
#   '34.5858853239',
#   '44.3490410592',
#   '45.6215182810'],
#  ['1.25',
#   '42.2146559819',
#   '40.8413237553',
#   '38.1636797932',
#   '42.0458138152',
#   '47.2088887407',
#   '36.3792464550',
#   '34.9736015106',
#   '35.9437713028',
#   '43.6408846543',
#   '36.4949200992',
#   '38.3187719448',
#   '42.4553920812'],
#  ['0.75',
#   '40.1274551528',
#   '46.3043951701',
#   '52.4807702475',
#   '49.8293193784',
#   '49.0875105777',
#   '43.9539520400',
#   '40.5844890124',
#   '41.1867189863',
#   '37.9333626014',
#   '34.2146212793',
#   '38.2084972720',
#   '40.1013821489'],
#  ['0.25',
#   '43.0534128186',
#   '44.6922389958',
#   '42.7410972295',
#   '46.4332682852',
#   '48.3543422435',
#   '40.8229365911',
#   '42.1039980689',
#   '35.6080309971',
#   '32.7291606229',
#   '30.6276372945',
#   '32.9537007882',
#   '40.6668144026'],
#  ['-0.25',
#   '45.6738586698',
#   '43.6624760577',
#   '42.2136186166',
#   '40.0039668287',
#   '40.7776700897',
#   '32.0106230150',
#   '34.2760447166',
#   '32.6117867112',
#   '39.5241810195',
#   '41.3984220287',
#   '32.3232085608',
#   '35.2360298608'],
#  ['-0.75',
#   '47.1986710370',
#   '41.2972598046',
#   '45.1226309787',
#   '37.7970735832',
#   '38.7017539396',
#   '39.0454574360',
#   '37.0748486067',
#   '25.9241108046',
#   '37.0647703381',
#   '38.7704660177',
#   '37.1711956869',
#   '39.1035848469'],
#  ['-1.25',
#   '49.8171877732',
#   '39.9807982242',
#   '38.4186162491',
#   '32.3336673654',
#   '36.5653528518',
#   '38.7377267578',
#   '33.5716420929',
#   '33.1231849823',
#   '35.8682450147',
#   '39.3382929887',
#   '37.6623244151',
#   '30.9494590027'],
#  ['-1.75',
#   '44.8916164984',
#   '40.4540297431',
#   '34.9790793619',
#   '38.7805544803',
#   '36.6522266935',
#   '41.7060387477',
#   '31.9219382503',
#   '42.9348596580',
#   '38.3487694557',
#   '38.7154924340',
#   '41.2733934499',
#   '41.4795934930']]
