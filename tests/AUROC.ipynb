# %%
import numpy as np
from scipy.stats import sem
from sklearn.metrics import roc_auc_score

y_pred = np.array([0.21, 0.32, 0.63, 0.35, 0.92, 0.79, 0.82, 0.99, 0.04])
y_true = np.array([0,    1,    0,    0,    1,    1,    0,    1,    0   ])

print("Original ROC area: {:0.3f}".format(roc_auc_score(y_true, y_pred)))

n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred), len(y_pred))
    if len(np.unique(y_true[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue

    score = roc_auc_score(y_true[indices], y_pred[indices])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Original ROC area: 0.800
# Bootstrap #1 ROC area: 1.000
# Bootstrap #2 ROC area: 0.857
# Bootstrap #3 ROC area: 0.778
# Bootstrap #4 ROC area: 0.778
# Bootstrap #5 ROC area: 0.700
# Bootstrap #6 ROC area: 0.700
# Bootstrap #7 ROC area: 0.650
# Bootstrap #8 ROC area: 0.950
# Bootstrap #9 ROC area: 1.000
# Bootstrap #10 ROC area: 0.833
# Bootstrap #11 ROC area: 0.900
# Bootstrap #12 ROC area: 1.000
# Bootstrap #13 ROC area: 1.000
# Bootstrap #14 ROC area: 0.600
# Bootstrap #16 ROC area: 0.900
# Bootstrap #17 ROC area: 0.714
# Bootstrap #18 ROC area: 1.000
# Bootstrap #19 ROC area: 0.750
# Bootstrap #20 ROC area: 0.800
# Bootstrap #21 ROC area: 1.000
# Bootstrap #22 ROC area: 1.000
# Bootstrap #23 ROC area: 0.667
# Bootstrap #24 ROC area: 0.889
# Bootstrap #25 ROC area: 1.000
# Bootstrap #26 ROC area: 1.000
# Bootstrap #27 ROC area: 0.700
# Bootstrap #28 ROC area: 1.000
# Bootstrap #29 ROC area: 0.800
# Bootstrap #30 ROC area: 0.900
# Bootstrap #31 ROC area: 1.000
# Bootstrap #32 ROC area: 1.000
# Bootstrap #33 ROC area: 0.778
# Bootstrap #34 ROC area: 0.700
# Bootstrap #35 ROC area: 0.643
# Bootstrap #36 ROC area: 0.500
# Bootstrap #37 ROC area: 1.000
# Bootstrap #38 ROC area: 0.900
# Bootstrap #39 ROC area: 0.800
# Bootstrap #40 ROC area: 0.900
# Bootstrap #41 ROC area: 0.900
# Bootstrap #42 ROC area: 0.950
# Bootstrap #43 ROC area: 0.750
# Bootstrap #44 ROC area: 0.850
# Bootstrap #45 ROC area: 0.778
# Bootstrap #46 ROC area: 0.667
# Bootstrap #47 ROC area: 0.700
# Bootstrap #48 ROC area: 1.000
# Bootstrap #49 ROC area: 0.778
# Bootstrap #51 ROC area: 0.875
# Bootstrap #52 ROC area: 1.000
# Bootstrap #53 ROC area: 1.000
# Bootstrap #54 ROC area: 0.800
# Bootstrap #55 ROC area: 1.000
# Bootstrap #56 ROC area: 0.714
# Bootstrap #57 ROC area: 0.643
# Bootstrap #58 ROC area: 1.000
# Bootstrap #59 ROC area: 0.800
# Bootstrap #60 ROC area: 0.889
# Bootstrap #61 ROC area: 0.875
# Bootstrap #62 ROC area: 1.000
# Bootstrap #63 ROC area: 0.786
# Bootstrap #64 ROC area: 0.900
# Bootstrap #65 ROC area: 0.833
# Bootstrap #66 ROC area: 0.889
# Bootstrap #67 ROC area: 1.000
# Bootstrap #68 ROC area: 0.778
# Bootstrap #69 ROC area: 0.850
# Bootstrap #70 ROC area: 0.286
# Bootstrap #71 ROC area: 0.650
# Bootstrap #72 ROC area: 1.000
# Bootstrap #73 ROC area: 0.600
# Bootstrap #74 ROC area: 1.000
# Bootstrap #75 ROC area: 0.714
# Bootstrap #76 ROC area: 1.000
# Bootstrap #77 ROC area: 1.000
# Bootstrap #78 ROC area: 0.600
# Bootstrap #79 ROC area: 0.667
# Bootstrap #80 ROC area: 0.875
# Bootstrap #81 ROC area: 0.800
# Bootstrap #82 ROC area: 0.944
# Bootstrap #83 ROC area: 0.833
# Bootstrap #84 ROC area: 1.000
# Bootstrap #85 ROC area: 0.889
# Bootstrap #86 ROC area: 0.850
# Bootstrap #87 ROC area: 1.000
# Bootstrap #88 ROC area: 0.722
# Bootstrap #89 ROC area: 0.950
# Bootstrap #90 ROC area: 0.800
# Bootstrap #91 ROC area: 1.000
# Bootstrap #92 ROC area: 0.900
# Bootstrap #93 ROC area: 0.889
# Bootstrap #94 ROC area: 0.850
# Bootstrap #95 ROC area: 0.889
# Bootstrap #96 ROC area: 0.857
# Bootstrap #97 ROC area: 0.889
# Bootstrap #98 ROC area: 0.750
# Bootstrap #99 ROC area: 0.889
# Bootstrap #100 ROC area: 0.900
# Bootstrap #101 ROC area: 0.900
# Bootstrap #102 ROC area: 0.900
# Bootstrap #103 ROC area: 1.000
# Bootstrap #104 ROC area: 0.650
# Bootstrap #105 ROC area: 0.750
# Bootstrap #106 ROC area: 0.900
# Bootstrap #107 ROC area: 1.000
# Bootstrap #108 ROC area: 1.000
# Bootstrap #109 ROC area: 0.778
# Bootstrap #110 ROC area: 0.571
# Bootstrap #111 ROC area: 0.714
# Bootstrap #112 ROC area: 0.950
# Bootstrap #113 ROC area: 0.850
# Bootstrap #114 ROC area: 0.600
# Bootstrap #115 ROC area: 0.400
# Bootstrap #116 ROC area: 0.700
# Bootstrap #117 ROC area: 0.950
# Bootstrap #118 ROC area: 0.778
# Bootstrap #119 ROC area: 0.500
# Bootstrap #120 ROC area: 0.800
# Bootstrap #121 ROC area: 1.000
# Bootstrap #122 ROC area: 0.800
# Bootstrap #123 ROC area: 0.950
# Bootstrap #124 ROC area: 0.778
# Bootstrap #125 ROC area: 0.556
# Bootstrap #126 ROC area: 1.000
# Bootstrap #127 ROC area: 0.600
# Bootstrap #128 ROC area: 1.000
# Bootstrap #129 ROC area: 0.850
# Bootstrap #130 ROC area: 0.778
# Bootstrap #131 ROC area: 0.444
# Bootstrap #132 ROC area: 0.700
# Bootstrap #133 ROC area: 0.611
# Bootstrap #134 ROC area: 0.167
# Bootstrap #135 ROC area: 1.000
# Bootstrap #136 ROC area: 0.800
# Bootstrap #137 ROC area: 1.000
# Bootstrap #138 ROC area: 0.750
# Bootstrap #139 ROC area: 0.850
# Bootstrap #140 ROC area: 0.900
# Bootstrap #141 ROC area: 0.667
# Bootstrap #142 ROC area: 0.850
# Bootstrap #143 ROC area: 0.889
# Bootstrap #144 ROC area: 1.000
# Bootstrap #145 ROC area: 0.889
# Bootstrap #146 ROC area: 0.950
# Bootstrap #147 ROC area: 0.889
# Bootstrap #148 ROC area: 0.550
# Bootstrap #149 ROC area: 0.800
# Bootstrap #150 ROC area: 0.600
# Bootstrap #151 ROC area: 0.889
# Bootstrap #152 ROC area: 0.333
# Bootstrap #153 ROC area: 0.250
# Bootstrap #154 ROC area: 1.000
# Bootstrap #155 ROC area: 0.889
# Bootstrap #156 ROC area: 0.889
# Bootstrap #157 ROC area: 1.000
# Bootstrap #158 ROC area: 1.000
# Bootstrap #159 ROC area: 1.000
# Bootstrap #160 ROC area: 1.000
# Bootstrap #161 ROC area: 0.950
# Bootstrap #162 ROC area: 0.722
# Bootstrap #163 ROC area: 0.500
# Bootstrap #164 ROC area: 0.850
# Bootstrap #165 ROC area: 0.611
# Bootstrap #166 ROC area: 0.786
# Bootstrap #167 ROC area: 0.556
# Bootstrap #168 ROC area: 0.929
# Bootstrap #169 ROC area: 0.850
# Bootstrap #170 ROC area: 0.400
# Bootstrap #171 ROC area: 0.700
# Bootstrap #172 ROC area: 0.800
# Bootstrap #173 ROC area: 0.650
# Bootstrap #174 ROC area: 0.950
# Bootstrap #175 ROC area: 0.950
# Bootstrap #176 ROC area: 1.000
# Bootstrap #177 ROC area: 0.889
# Bootstrap #178 ROC area: 0.950
# Bootstrap #179 ROC area: 0.800
# Bootstrap #180 ROC area: 0.600
# Bootstrap #181 ROC area: 0.600
# Bootstrap #182 ROC area: 0.556
# Bootstrap #183 ROC area: 0.950
# Bootstrap #184 ROC area: 0.900
# Bootstrap #185 ROC area: 0.944
# Bootstrap #186 ROC area: 0.500
# Bootstrap #187 ROC area: 0.900
# Bootstrap #188 ROC area: 1.000
# Bootstrap #189 ROC area: 0.889
# Bootstrap #190 ROC area: 0.556
# Bootstrap #191 ROC area: 0.944
# Bootstrap #192 ROC area: 0.400
# Bootstrap #193 ROC area: 1.000
# Bootstrap #194 ROC area: 0.778
# Bootstrap #195 ROC area: 1.000
# Bootstrap #196 ROC area: 0.800
# Bootstrap #197 ROC area: 0.667
# Bootstrap #198 ROC area: 0.800
# Bootstrap #199 ROC area: 0.667
# Bootstrap #200 ROC area: 0.857
# Bootstrap #201 ROC area: 0.944
# Bootstrap #202 ROC area: 0.850
# Bootstrap #203 ROC area: 0.857
# Bootstrap #204 ROC area: 0.350
# Bootstrap #205 ROC area: 0.889
# Bootstrap #206 ROC area: 0.950
# Bootstrap #207 ROC area: 1.000
# Bootstrap #208 ROC area: 0.650
# Bootstrap #209 ROC area: 0.850
# Bootstrap #210 ROC area: 0.429
# Bootstrap #211 ROC area: 0.889
# Bootstrap #212 ROC area: 0.550
# Bootstrap #213 ROC area: 0.700
# Bootstrap #214 ROC area: 1.000
# Bootstrap #215 ROC area: 0.700
# Bootstrap #216 ROC area: 0.350
# Bootstrap #217 ROC area: 0.667
# Bootstrap #218 ROC area: 1.000
# Bootstrap #219 ROC area: 0.611
# Bootstrap #220 ROC area: 0.800
# Bootstrap #221 ROC area: 0.500
# Bootstrap #222 ROC area: 0.857
# Bootstrap #223 ROC area: 0.778
# Bootstrap #224 ROC area: 0.850
# Bootstrap #225 ROC area: 1.000
# Bootstrap #226 ROC area: 0.889
# Bootstrap #227 ROC area: 1.000
# Bootstrap #228 ROC area: 1.000
# Bootstrap #229 ROC area: 1.000
# Bootstrap #230 ROC area: 1.000
# Bootstrap #231 ROC area: 0.571
# Bootstrap #232 ROC area: 0.722
# Bootstrap #233 ROC area: 0.900
# Bootstrap #234 ROC area: 0.850
# Bootstrap #235 ROC area: 0.850
# Bootstrap #236 ROC area: 0.444
# Bootstrap #237 ROC area: 0.800
# Bootstrap #238 ROC area: 0.900
# Bootstrap #239 ROC area: 0.850
# Bootstrap #240 ROC area: 0.778
# Bootstrap #241 ROC area: 0.778
# Bootstrap #242 ROC area: 1.000
# Bootstrap #243 ROC area: 0.786
# Bootstrap #244 ROC area: 1.000
# Bootstrap #245 ROC area: 0.600
# Bootstrap #246 ROC area: 1.000
# Bootstrap #247 ROC area: 0.500
# Bootstrap #248 ROC area: 0.833
# Bootstrap #249 ROC area: 0.900
# Bootstrap #250 ROC area: 1.000
# Bootstrap #251 ROC area: 0.650
# Bootstrap #252 ROC area: 1.000
# Bootstrap #253 ROC area: 0.900
# Bootstrap #254 ROC area: 0.900
# Bootstrap #255 ROC area: 0.750
# Bootstrap #256 ROC area: 0.889
# Bootstrap #257 ROC area: 1.000
# Bootstrap #258 ROC area: 0.889
# Bootstrap #259 ROC area: 0.700
# Bootstrap #260 ROC area: 1.000
# Bootstrap #261 ROC area: 0.556
# Bootstrap #262 ROC area: 0.944
# Bootstrap #263 ROC area: 1.000
# Bootstrap #264 ROC area: 0.833
# Bootstrap #265 ROC area: 0.611
# Bootstrap #266 ROC area: 1.000
# Bootstrap #267 ROC area: 0.550
# Bootstrap #268 ROC area: 0.889
# Bootstrap #269 ROC area: 0.778
# Bootstrap #270 ROC area: 0.800
# Bootstrap #271 ROC area: 0.778
# Bootstrap #272 ROC area: 0.833
# Bootstrap #273 ROC area: 0.850
# Bootstrap #274 ROC area: 0.778
# Bootstrap #275 ROC area: 0.650
# Bootstrap #276 ROC area: 1.000
# Bootstrap #277 ROC area: 1.000
# Bootstrap #278 ROC area: 0.444
# Bootstrap #279 ROC area: 1.000
# Bootstrap #280 ROC area: 0.900
# Bootstrap #282 ROC area: 1.000
# Bootstrap #283 ROC area: 1.000
# Bootstrap #284 ROC area: 0.850
# Bootstrap #285 ROC area: 0.889
# Bootstrap #286 ROC area: 0.889
# Bootstrap #287 ROC area: 0.900
# Bootstrap #288 ROC area: 0.750
# Bootstrap #289 ROC area: 0.700
# Bootstrap #290 ROC area: 0.722
# Bootstrap #291 ROC area: 1.000
# Bootstrap #292 ROC area: 0.944
# Bootstrap #293 ROC area: 1.000
# Bootstrap #294 ROC area: 1.000
# Bootstrap #295 ROC area: 1.000
# Bootstrap #296 ROC area: 0.700
# Bootstrap #297 ROC area: 0.600
# Bootstrap #298 ROC area: 0.571
# Bootstrap #299 ROC area: 0.667
# Bootstrap #300 ROC area: 0.800
# Bootstrap #301 ROC area: 1.000
# Bootstrap #302 ROC area: 0.750
# Bootstrap #303 ROC area: 0.750
# Bootstrap #304 ROC area: 0.800
# Bootstrap #305 ROC area: 0.833
# Bootstrap #306 ROC area: 0.944
# Bootstrap #307 ROC area: 0.850
# Bootstrap #308 ROC area: 0.778
# Bootstrap #309 ROC area: 0.833
# Bootstrap #310 ROC area: 0.850
# Bootstrap #311 ROC area: 0.722
# Bootstrap #312 ROC area: 0.556
# Bootstrap #313 ROC area: 0.944
# Bootstrap #314 ROC area: 0.889
# Bootstrap #315 ROC area: 0.900
# Bootstrap #316 ROC area: 0.833
# Bootstrap #317 ROC area: 0.833
# Bootstrap #318 ROC area: 0.643
# Bootstrap #319 ROC area: 0.944
# Bootstrap #320 ROC area: 0.857
# Bootstrap #321 ROC area: 0.850
# Bootstrap #322 ROC area: 1.000
# Bootstrap #323 ROC area: 0.900
# Bootstrap #324 ROC area: 0.550
# Bootstrap #325 ROC area: 0.556
# Bootstrap #326 ROC area: 0.600
# Bootstrap #327 ROC area: 0.900
# Bootstrap #328 ROC area: 0.857
# Bootstrap #329 ROC area: 0.600
# Bootstrap #330 ROC area: 0.389
# Bootstrap #331 ROC area: 1.000
# Bootstrap #332 ROC area: 0.900
# Bootstrap #333 ROC area: 0.429
# Bootstrap #334 ROC area: 0.944
# Bootstrap #335 ROC area: 1.000
# Bootstrap #336 ROC area: 1.000
# Bootstrap #337 ROC area: 0.778
# Bootstrap #338 ROC area: 0.750
# Bootstrap #339 ROC area: 0.800
# Bootstrap #340 ROC area: 0.722
# Bootstrap #341 ROC area: 1.000
# Bootstrap #342 ROC area: 0.929
# Bootstrap #343 ROC area: 1.000
# Bootstrap #344 ROC area: 0.900
# Bootstrap #345 ROC area: 0.800
# Bootstrap #346 ROC area: 1.000
# Bootstrap #347 ROC area: 0.950
# Bootstrap #348 ROC area: 0.556
# Bootstrap #349 ROC area: 0.850
# Bootstrap #350 ROC area: 1.000
# Bootstrap #351 ROC area: 1.000
# Bootstrap #352 ROC area: 0.800
# Bootstrap #353 ROC area: 0.875
# Bootstrap #354 ROC area: 0.889
# Bootstrap #355 ROC area: 0.500
# Bootstrap #356 ROC area: 0.500
# Bootstrap #357 ROC area: 0.850
# Bootstrap #358 ROC area: 1.000
# Bootstrap #359 ROC area: 0.800
# Bootstrap #360 ROC area: 0.722
# Bootstrap #361 ROC area: 1.000
# Bootstrap #362 ROC area: 0.550
# Bootstrap #363 ROC area: 0.929
# Bootstrap #364 ROC area: 0.850
# Bootstrap #365 ROC area: 1.000
# Bootstrap #366 ROC area: 0.643
# Bootstrap #367 ROC area: 0.800
# Bootstrap #368 ROC area: 0.850
# Bootstrap #369 ROC area: 0.950
# Bootstrap #370 ROC area: 0.800
# Bootstrap #371 ROC area: 1.000
# Bootstrap #372 ROC area: 0.667
# Bootstrap #373 ROC area: 0.786
# Bootstrap #374 ROC area: 1.000
# Bootstrap #375 ROC area: 1.000
# Bootstrap #376 ROC area: 0.700
# Bootstrap #377 ROC area: 0.900
# Bootstrap #379 ROC area: 0.556
# Bootstrap #380 ROC area: 1.000
# Bootstrap #381 ROC area: 1.000
# Bootstrap #382 ROC area: 0.800
# Bootstrap #383 ROC area: 0.333
# Bootstrap #384 ROC area: 1.000
# Bootstrap #385 ROC area: 0.950
# Bootstrap #386 ROC area: 0.600
# Bootstrap #387 ROC area: 0.700
# Bootstrap #388 ROC area: 1.000
# Bootstrap #389 ROC area: 0.500
# Bootstrap #390 ROC area: 0.550
# Bootstrap #391 ROC area: 0.600
# Bootstrap #392 ROC area: 0.833
# Bootstrap #393 ROC area: 1.000
# Bootstrap #394 ROC area: 0.625
# Bootstrap #395 ROC area: 0.833
# Bootstrap #396 ROC area: 0.778
# Bootstrap #397 ROC area: 0.889
# Bootstrap #398 ROC area: 0.800
# Bootstrap #399 ROC area: 0.550
# Bootstrap #400 ROC area: 0.944
# Bootstrap #401 ROC area: 0.850
# Bootstrap #402 ROC area: 0.625
# Bootstrap #403 ROC area: 0.700
# Bootstrap #404 ROC area: 0.750
# Bootstrap #405 ROC area: 0.800
# Bootstrap #406 ROC area: 1.000
# Bootstrap #407 ROC area: 1.000
# Bootstrap #408 ROC area: 0.889
# Bootstrap #409 ROC area: 0.778
# Bootstrap #410 ROC area: 1.000
# Bootstrap #411 ROC area: 0.889
# Bootstrap #412 ROC area: 0.500
# Bootstrap #413 ROC area: 1.000
# Bootstrap #414 ROC area: 0.650
# Bootstrap #415 ROC area: 1.000
# Bootstrap #416 ROC area: 1.000
# Bootstrap #417 ROC area: 1.000
# Bootstrap #418 ROC area: 0.722
# Bootstrap #419 ROC area: 0.889
# Bootstrap #420 ROC area: 0.700
# Bootstrap #421 ROC area: 0.611
# Bootstrap #422 ROC area: 0.950
# Bootstrap #423 ROC area: 0.857
# Bootstrap #424 ROC area: 0.900
# Bootstrap #425 ROC area: 0.833
# Bootstrap #426 ROC area: 0.722
# Bootstrap #427 ROC area: 0.778
# Bootstrap #428 ROC area: 1.000
# Bootstrap #429 ROC area: 0.929
# Bootstrap #430 ROC area: 0.625
# Bootstrap #431 ROC area: 1.000
# Bootstrap #432 ROC area: 0.857
# Bootstrap #433 ROC area: 1.000
# Bootstrap #434 ROC area: 0.444
# Bootstrap #435 ROC area: 0.800
# Bootstrap #436 ROC area: 0.500
# Bootstrap #437 ROC area: 0.900
# Bootstrap #438 ROC area: 0.800
# Bootstrap #439 ROC area: 0.600
# Bootstrap #440 ROC area: 0.778
# Bootstrap #441 ROC area: 1.000
# Bootstrap #442 ROC area: 1.000
# Bootstrap #443 ROC area: 1.000
# Bootstrap #444 ROC area: 0.550
# Bootstrap #445 ROC area: 0.800
# Bootstrap #446 ROC area: 1.000
# Bootstrap #447 ROC area: 0.700
# Bootstrap #448 ROC area: 0.571
# Bootstrap #449 ROC area: 1.000
# Bootstrap #450 ROC area: 0.900
# Bootstrap #451 ROC area: 0.833
# Bootstrap #452 ROC area: 0.357
# Bootstrap #453 ROC area: 1.000
# Bootstrap #454 ROC area: 0.900
# Bootstrap #455 ROC area: 0.722
# Bootstrap #456 ROC area: 1.000
# Bootstrap #457 ROC area: 0.571
# Bootstrap #458 ROC area: 0.850
# Bootstrap #459 ROC area: 0.800
# Bootstrap #460 ROC area: 0.700
# Bootstrap #461 ROC area: 1.000
# Bootstrap #462 ROC area: 0.857
# Bootstrap #463 ROC area: 1.000
# Bootstrap #464 ROC area: 0.786
# Bootstrap #465 ROC area: 1.000
# Bootstrap #466 ROC area: 0.850
# Bootstrap #467 ROC area: 0.667
# Bootstrap #468 ROC area: 1.000
# Bootstrap #469 ROC area: 0.850
# Bootstrap #470 ROC area: 0.833
# Bootstrap #471 ROC area: 0.850
# Bootstrap #472 ROC area: 0.850
# Bootstrap #473 ROC area: 0.286
# Bootstrap #474 ROC area: 0.833
# Bootstrap #475 ROC area: 1.000
# Bootstrap #476 ROC area: 0.750
# Bootstrap #477 ROC area: 0.850
# Bootstrap #478 ROC area: 0.889
# Bootstrap #479 ROC area: 0.750
# Bootstrap #480 ROC area: 0.750
# Bootstrap #481 ROC area: 1.000
# Bootstrap #482 ROC area: 1.000
# Bootstrap #483 ROC area: 1.000
# Bootstrap #484 ROC area: 0.800
# Bootstrap #485 ROC area: 0.444
# Bootstrap #486 ROC area: 1.000
# Bootstrap #487 ROC area: 0.722
# Bootstrap #488 ROC area: 0.800
# Bootstrap #489 ROC area: 0.700
# Bootstrap #490 ROC area: 0.429
# Bootstrap #491 ROC area: 0.800
# Bootstrap #492 ROC area: 1.000
# Bootstrap #493 ROC area: 1.000
# Bootstrap #494 ROC area: 0.625
# Bootstrap #495 ROC area: 0.778
# Bootstrap #496 ROC area: 0.714
# Bootstrap #497 ROC area: 0.600
# Bootstrap #498 ROC area: 0.722
# Bootstrap #499 ROC area: 0.800
# Bootstrap #500 ROC area: 0.900
# Bootstrap #501 ROC area: 1.000
# Bootstrap #502 ROC area: 0.700
# Bootstrap #503 ROC area: 0.600
# Bootstrap #504 ROC area: 0.857
# Bootstrap #505 ROC area: 0.556
# Bootstrap #506 ROC area: 0.667
# Bootstrap #507 ROC area: 0.667
# Bootstrap #508 ROC area: 1.000
# Bootstrap #509 ROC area: 0.800
# Bootstrap #510 ROC area: 0.700
# Bootstrap #511 ROC area: 0.950
# Bootstrap #512 ROC area: 0.889
# Bootstrap #513 ROC area: 0.778
# Bootstrap #514 ROC area: 0.700
# Bootstrap #515 ROC area: 0.714
# Bootstrap #516 ROC area: 1.000
# Bootstrap #517 ROC area: 0.667
# Bootstrap #518 ROC area: 0.833
# Bootstrap #519 ROC area: 0.850
# Bootstrap #520 ROC area: 0.944
# Bootstrap #521 ROC area: 0.850
# Bootstrap #522 ROC area: 0.778
# Bootstrap #523 ROC area: 0.900
# Bootstrap #524 ROC area: 1.000
# Bootstrap #525 ROC area: 1.000
# Bootstrap #526 ROC area: 0.944
# Bootstrap #527 ROC area: 0.550
# Bootstrap #528 ROC area: 1.000
# Bootstrap #529 ROC area: 0.900
# Bootstrap #530 ROC area: 1.000
# Bootstrap #531 ROC area: 0.500
# Bootstrap #532 ROC area: 1.000
# Bootstrap #533 ROC area: 0.850
# Bootstrap #534 ROC area: 0.714
# Bootstrap #535 ROC area: 0.800
# Bootstrap #536 ROC area: 0.722
# Bootstrap #537 ROC area: 0.444
# Bootstrap #538 ROC area: 0.667
# Bootstrap #539 ROC area: 0.667
# Bootstrap #540 ROC area: 0.944
# Bootstrap #541 ROC area: 0.750
# Bootstrap #542 ROC area: 0.444
# Bootstrap #543 ROC area: 0.700
# Bootstrap #544 ROC area: 0.714
# Bootstrap #545 ROC area: 0.850
# Bootstrap #546 ROC area: 1.000
# Bootstrap #547 ROC area: 1.000
# Bootstrap #548 ROC area: 0.700
# Bootstrap #549 ROC area: 1.000
# Bootstrap #550 ROC area: 0.929
# Bootstrap #551 ROC area: 0.800
# Bootstrap #552 ROC area: 0.800
# Bootstrap #553 ROC area: 0.389
# Bootstrap #554 ROC area: 0.889
# Bootstrap #555 ROC area: 0.600
# Bootstrap #556 ROC area: 0.643
# Bootstrap #557 ROC area: 0.550
# Bootstrap #558 ROC area: 0.900
# Bootstrap #559 ROC area: 0.643
# Bootstrap #560 ROC area: 0.500
# Bootstrap #561 ROC area: 0.950
# Bootstrap #562 ROC area: 1.000
# Bootstrap #563 ROC area: 0.722
# Bootstrap #564 ROC area: 0.778
# Bootstrap #565 ROC area: 0.571
# Bootstrap #566 ROC area: 0.786
# Bootstrap #567 ROC area: 0.778
# Bootstrap #568 ROC area: 0.778
# Bootstrap #569 ROC area: 1.000
# Bootstrap #570 ROC area: 0.700
# Bootstrap #571 ROC area: 1.000
# Bootstrap #572 ROC area: 0.600
# Bootstrap #573 ROC area: 0.643
# Bootstrap #574 ROC area: 0.400
# Bootstrap #575 ROC area: 1.000
# Bootstrap #576 ROC area: 0.625
# Bootstrap #577 ROC area: 0.850
# Bootstrap #578 ROC area: 0.600
# Bootstrap #579 ROC area: 0.750
# Bootstrap #580 ROC area: 0.900
# Bootstrap #581 ROC area: 0.944
# Bootstrap #582 ROC area: 0.700
# Bootstrap #583 ROC area: 0.833
# Bootstrap #584 ROC area: 0.444
# Bootstrap #585 ROC area: 0.600
# Bootstrap #586 ROC area: 0.850
# Bootstrap #587 ROC area: 0.444
# Bootstrap #588 ROC area: 1.000
# Bootstrap #589 ROC area: 0.700
# Bootstrap #590 ROC area: 0.800
# Bootstrap #591 ROC area: 0.950
# Bootstrap #592 ROC area: 0.333
# Bootstrap #593 ROC area: 0.857
# Bootstrap #594 ROC area: 0.600
# Bootstrap #595 ROC area: 0.700
# Bootstrap #596 ROC area: 0.400
# Bootstrap #597 ROC area: 0.900
# Bootstrap #598 ROC area: 1.000
# Bootstrap #599 ROC area: 0.889
# Bootstrap #600 ROC area: 0.500
# Bootstrap #601 ROC area: 0.800
# Bootstrap #602 ROC area: 0.556
# Bootstrap #603 ROC area: 1.000
# Bootstrap #604 ROC area: 0.714
# Bootstrap #605 ROC area: 0.600
# Bootstrap #606 ROC area: 0.900
# Bootstrap #607 ROC area: 1.000
# Bootstrap #608 ROC area: 0.286
# Bootstrap #609 ROC area: 0.429
# Bootstrap #610 ROC area: 0.667
# Bootstrap #611 ROC area: 0.778
# Bootstrap #612 ROC area: 0.722
# Bootstrap #613 ROC area: 1.000
# Bootstrap #614 ROC area: 0.944
# Bootstrap #615 ROC area: 0.857
# Bootstrap #616 ROC area: 0.700
# Bootstrap #617 ROC area: 1.000
# Bootstrap #618 ROC area: 0.778
# Bootstrap #619 ROC area: 1.000
# Bootstrap #620 ROC area: 0.900
# Bootstrap #621 ROC area: 0.667
# Bootstrap #622 ROC area: 0.714
# Bootstrap #623 ROC area: 0.700
# Bootstrap #624 ROC area: 0.333
# Bootstrap #625 ROC area: 0.667
# Bootstrap #626 ROC area: 0.900
# Bootstrap #627 ROC area: 0.950
# Bootstrap #628 ROC area: 0.944
# Bootstrap #629 ROC area: 0.571
# Bootstrap #630 ROC area: 0.650
# Bootstrap #631 ROC area: 0.800
# Bootstrap #632 ROC area: 0.850
# Bootstrap #633 ROC area: 0.571
# Bootstrap #634 ROC area: 0.400
# Bootstrap #635 ROC area: 0.889
# Bootstrap #636 ROC area: 0.889
# Bootstrap #637 ROC area: 0.786
# Bootstrap #638 ROC area: 0.700
# Bootstrap #639 ROC area: 0.550
# Bootstrap #640 ROC area: 0.850
# Bootstrap #641 ROC area: 0.750
# Bootstrap #642 ROC area: 1.000
# Bootstrap #643 ROC area: 0.571
# Bootstrap #644 ROC area: 1.000
# Bootstrap #645 ROC area: 0.850
# Bootstrap #646 ROC area: 0.900
# Bootstrap #647 ROC area: 1.000
# Bootstrap #648 ROC area: 0.556
# Bootstrap #649 ROC area: 0.950
# Bootstrap #650 ROC area: 1.000
# Bootstrap #651 ROC area: 0.600
# Bootstrap #652 ROC area: 0.667
# Bootstrap #653 ROC area: 0.800
# Bootstrap #654 ROC area: 0.667
# Bootstrap #655 ROC area: 0.778
# Bootstrap #656 ROC area: 0.778
# Bootstrap #657 ROC area: 0.700
# Bootstrap #658 ROC area: 0.850
# Bootstrap #659 ROC area: 0.700
# Bootstrap #660 ROC area: 0.444
# Bootstrap #661 ROC area: 0.900
# Bootstrap #662 ROC area: 1.000
# Bootstrap #663 ROC area: 0.850
# Bootstrap #664 ROC area: 0.944
# Bootstrap #665 ROC area: 0.900
# Bootstrap #666 ROC area: 0.833
# Bootstrap #667 ROC area: 0.722
# Bootstrap #668 ROC area: 0.850
# Bootstrap #669 ROC area: 0.722
# Bootstrap #670 ROC area: 0.667
# Bootstrap #671 ROC area: 0.800
# Bootstrap #672 ROC area: 1.000
# Bootstrap #673 ROC area: 0.667
# Bootstrap #674 ROC area: 1.000
# Bootstrap #675 ROC area: 0.600
# Bootstrap #676 ROC area: 0.700
# Bootstrap #677 ROC area: 0.722
# Bootstrap #678 ROC area: 0.600
# Bootstrap #679 ROC area: 0.600
# Bootstrap #680 ROC area: 0.250
# Bootstrap #681 ROC area: 0.500
# Bootstrap #682 ROC area: 0.889
# Bootstrap #683 ROC area: 0.750
# Bootstrap #684 ROC area: 1.000
# Bootstrap #685 ROC area: 1.000
# Bootstrap #686 ROC area: 1.000
# Bootstrap #687 ROC area: 0.389
# Bootstrap #688 ROC area: 1.000
# Bootstrap #689 ROC area: 0.950
# Bootstrap #690 ROC area: 0.611
# Bootstrap #691 ROC area: 0.571
# Bootstrap #692 ROC area: 0.700
# Bootstrap #693 ROC area: 0.850
# Bootstrap #694 ROC area: 0.667
# Bootstrap #695 ROC area: 0.667
# Bootstrap #696 ROC area: 0.650
# Bootstrap #697 ROC area: 0.944
# Bootstrap #698 ROC area: 0.750
# Bootstrap #699 ROC area: 0.643
# Bootstrap #700 ROC area: 0.556
# Bootstrap #701 ROC area: 0.900
# Bootstrap #702 ROC area: 1.000
# Bootstrap #703 ROC area: 0.714
# Bootstrap #704 ROC area: 0.889
# Bootstrap #705 ROC area: 0.850
# Bootstrap #706 ROC area: 0.556
# Bootstrap #707 ROC area: 1.000
# Bootstrap #708 ROC area: 0.833
# Bootstrap #709 ROC area: 0.850
# Bootstrap #710 ROC area: 0.389
# Bootstrap #711 ROC area: 1.000
# Bootstrap #712 ROC area: 0.950
# Bootstrap #713 ROC area: 0.833
# Bootstrap #714 ROC area: 0.167
# Bootstrap #715 ROC area: 0.714
# Bootstrap #716 ROC area: 0.800
# Bootstrap #717 ROC area: 0.944
# Bootstrap #718 ROC area: 1.000
# Bootstrap #719 ROC area: 0.500
# Bootstrap #720 ROC area: 0.850
# Bootstrap #721 ROC area: 0.250
# Bootstrap #722 ROC area: 0.722
# Bootstrap #723 ROC area: 0.857
# Bootstrap #724 ROC area: 0.850
# Bootstrap #725 ROC area: 0.500
# Bootstrap #726 ROC area: 0.800
# Bootstrap #727 ROC area: 0.900
# Bootstrap #728 ROC area: 0.250
# Bootstrap #729 ROC area: 0.778
# Bootstrap #730 ROC area: 0.600
# Bootstrap #731 ROC area: 0.850
# Bootstrap #732 ROC area: 0.571
# Bootstrap #733 ROC area: 0.833
# Bootstrap #734 ROC area: 0.800
# Bootstrap #735 ROC area: 1.000
# Bootstrap #736 ROC area: 0.900
# Bootstrap #737 ROC area: 0.850
# Bootstrap #738 ROC area: 0.778
# Bootstrap #739 ROC area: 0.500
# Bootstrap #740 ROC area: 0.900
# Bootstrap #741 ROC area: 0.400
# Bootstrap #742 ROC area: 0.667
# Bootstrap #743 ROC area: 0.833
# Bootstrap #744 ROC area: 0.700
# Bootstrap #745 ROC area: 0.650
# Bootstrap #746 ROC area: 0.900
# Bootstrap #747 ROC area: 0.800
# Bootstrap #748 ROC area: 0.700
# Bootstrap #749 ROC area: 0.950
# Bootstrap #750 ROC area: 0.778
# Bootstrap #751 ROC area: 0.778
# Bootstrap #752 ROC area: 0.778
# Bootstrap #753 ROC area: 1.000
# Bootstrap #754 ROC area: 0.750
# Bootstrap #755 ROC area: 0.929
# Bootstrap #756 ROC area: 0.700
# Bootstrap #757 ROC area: 0.833
# Bootstrap #758 ROC area: 0.444
# Bootstrap #759 ROC area: 1.000
# Bootstrap #760 ROC area: 0.722
# Bootstrap #761 ROC area: 0.900
# Bootstrap #762 ROC area: 0.900
# Bootstrap #763 ROC area: 0.778
# Bootstrap #764 ROC area: 0.950
# Bootstrap #765 ROC area: 0.778
# Bootstrap #766 ROC area: 0.850
# Bootstrap #767 ROC area: 0.800
# Bootstrap #768 ROC area: 0.889
# Bootstrap #769 ROC area: 0.500
# Bootstrap #770 ROC area: 0.571
# Bootstrap #771 ROC area: 0.550
# Bootstrap #772 ROC area: 0.900
# Bootstrap #773 ROC area: 0.778
# Bootstrap #774 ROC area: 0.900
# Bootstrap #775 ROC area: 0.400
# Bootstrap #776 ROC area: 0.929
# Bootstrap #777 ROC area: 1.000
# Bootstrap #778 ROC area: 0.700
# Bootstrap #779 ROC area: 0.714
# Bootstrap #780 ROC area: 0.900
# Bootstrap #781 ROC area: 0.450
# Bootstrap #782 ROC area: 0.944
# Bootstrap #783 ROC area: 0.143
# Bootstrap #784 ROC area: 1.000
# Bootstrap #785 ROC area: 1.000
# Bootstrap #786 ROC area: 1.000
# Bootstrap #787 ROC area: 0.778
# Bootstrap #788 ROC area: 0.950
# Bootstrap #789 ROC area: 0.700
# Bootstrap #790 ROC area: 0.600
# Bootstrap #791 ROC area: 0.944
# Bootstrap #792 ROC area: 1.000
# Bootstrap #793 ROC area: 1.000
# Bootstrap #794 ROC area: 1.000
# Bootstrap #795 ROC area: 0.900
# Bootstrap #796 ROC area: 0.778
# Bootstrap #797 ROC area: 1.000
# Bootstrap #798 ROC area: 0.550
# Bootstrap #799 ROC area: 1.000
# Bootstrap #800 ROC area: 0.900
# Bootstrap #801 ROC area: 0.650
# Bootstrap #802 ROC area: 0.786
# Bootstrap #803 ROC area: 1.000
# Bootstrap #804 ROC area: 0.500
# Bootstrap #805 ROC area: 0.857
# Bootstrap #806 ROC area: 1.000
# Bootstrap #807 ROC area: 0.800
# Bootstrap #808 ROC area: 0.571
# Bootstrap #809 ROC area: 0.700
# Bootstrap #810 ROC area: 0.429
# Bootstrap #811 ROC area: 0.800
# Bootstrap #812 ROC area: 0.833
# Bootstrap #813 ROC area: 0.667
# Bootstrap #814 ROC area: 1.000
# Bootstrap #815 ROC area: 1.000
# Bootstrap #816 ROC area: 1.000
# Bootstrap #817 ROC area: 0.200
# Bootstrap #818 ROC area: 0.900
# Bootstrap #819 ROC area: 0.650
# Bootstrap #820 ROC area: 0.667
# Bootstrap #821 ROC area: 0.929
# Bootstrap #822 ROC area: 0.714
# Bootstrap #823 ROC area: 0.800
# Bootstrap #824 ROC area: 0.900
# Bootstrap #825 ROC area: 1.000
# Bootstrap #826 ROC area: 0.850
# Bootstrap #827 ROC area: 0.950
# Bootstrap #828 ROC area: 1.000
# Bootstrap #829 ROC area: 0.667
# Bootstrap #830 ROC area: 1.000
# Bootstrap #831 ROC area: 1.000
# Bootstrap #832 ROC area: 0.333
# Bootstrap #833 ROC area: 0.850
# Bootstrap #834 ROC area: 0.600
# Bootstrap #835 ROC area: 0.556
# Bootstrap #836 ROC area: 0.750
# Bootstrap #837 ROC area: 0.750
# Bootstrap #838 ROC area: 1.000
# Bootstrap #839 ROC area: 0.900
# Bootstrap #840 ROC area: 0.722
# Bootstrap #841 ROC area: 0.722
# Bootstrap #842 ROC area: 1.000
# Bootstrap #843 ROC area: 0.650
# Bootstrap #844 ROC area: 0.900
# Bootstrap #845 ROC area: 0.800
# Bootstrap #846 ROC area: 0.667
# Bootstrap #847 ROC area: 1.000
# Bootstrap #848 ROC area: 0.667
# Bootstrap #849 ROC area: 0.750
# Bootstrap #850 ROC area: 1.000
# Bootstrap #851 ROC area: 0.600
# Bootstrap #852 ROC area: 0.667
# Bootstrap #853 ROC area: 0.857
# Bootstrap #854 ROC area: 0.900
# Bootstrap #855 ROC area: 0.833
# Bootstrap #856 ROC area: 0.700
# Bootstrap #857 ROC area: 1.000
# Bootstrap #858 ROC area: 0.667
# Bootstrap #859 ROC area: 0.500
# Bootstrap #860 ROC area: 0.857
# Bootstrap #861 ROC area: 0.778
# Bootstrap #862 ROC area: 0.900
# Bootstrap #863 ROC area: 0.850
# Bootstrap #864 ROC area: 0.556
# Bootstrap #865 ROC area: 0.800
# Bootstrap #866 ROC area: 1.000
# Bootstrap #867 ROC area: 1.000
# Bootstrap #868 ROC area: 1.000
# Bootstrap #869 ROC area: 0.800
# Bootstrap #870 ROC area: 0.889
# Bootstrap #871 ROC area: 0.833
# Bootstrap #872 ROC area: 0.778
# Bootstrap #873 ROC area: 0.850
# Bootstrap #874 ROC area: 0.889
# Bootstrap #875 ROC area: 1.000
# Bootstrap #876 ROC area: 0.714
# Bootstrap #877 ROC area: 1.000
# Bootstrap #878 ROC area: 0.778
# Bootstrap #879 ROC area: 0.714
# Bootstrap #880 ROC area: 1.000
# Bootstrap #881 ROC area: 0.833
# Bootstrap #882 ROC area: 0.750
# Bootstrap #883 ROC area: 0.950
# Bootstrap #884 ROC area: 0.800
# Bootstrap #885 ROC area: 0.600
# Bootstrap #886 ROC area: 0.500
# Bootstrap #887 ROC area: 1.000
# Bootstrap #888 ROC area: 0.667
# Bootstrap #889 ROC area: 0.556
# Bootstrap #890 ROC area: 1.000
# Bootstrap #891 ROC area: 0.900
# Bootstrap #892 ROC area: 0.550
# Bootstrap #893 ROC area: 0.714
# Bootstrap #894 ROC area: 1.000
# Bootstrap #895 ROC area: 0.700
# Bootstrap #896 ROC area: 0.778
# Bootstrap #897 ROC area: 0.800
# Bootstrap #898 ROC area: 0.786
# Bootstrap #899 ROC area: 0.667
# Bootstrap #900 ROC area: 0.850
# Bootstrap #901 ROC area: 0.786
# Bootstrap #902 ROC area: 0.650
# Bootstrap #903 ROC area: 0.929
# Bootstrap #904 ROC area: 0.889
# Bootstrap #905 ROC area: 0.667
# Bootstrap #906 ROC area: 0.850
# Bootstrap #907 ROC area: 0.950
# Bootstrap #908 ROC area: 0.929
# Bootstrap #909 ROC area: 0.800
# Bootstrap #910 ROC area: 1.000
# Bootstrap #911 ROC area: 1.000
# Bootstrap #912 ROC area: 0.778
# Bootstrap #913 ROC area: 0.429
# Bootstrap #914 ROC area: 0.800
# Bootstrap #915 ROC area: 0.950
# Bootstrap #916 ROC area: 0.889
# Bootstrap #917 ROC area: 0.857
# Bootstrap #918 ROC area: 1.000
# Bootstrap #919 ROC area: 0.929
# Bootstrap #920 ROC area: 1.000
# Bootstrap #921 ROC area: 1.000
# Bootstrap #922 ROC area: 0.286
# Bootstrap #923 ROC area: 0.929
# Bootstrap #924 ROC area: 0.700
# Bootstrap #925 ROC area: 1.000
# Bootstrap #926 ROC area: 0.800
# Bootstrap #927 ROC area: 1.000
# Bootstrap #928 ROC area: 0.778
# Bootstrap #929 ROC area: 0.786
# Bootstrap #930 ROC area: 1.000
# Bootstrap #931 ROC area: 0.929
# Bootstrap #932 ROC area: 1.000
# Bootstrap #933 ROC area: 0.778
# Bootstrap #934 ROC area: 0.667
# Bootstrap #935 ROC area: 0.850
# Bootstrap #936 ROC area: 0.700
# Bootstrap #937 ROC area: 0.900
# Bootstrap #938 ROC area: 0.800
# Bootstrap #939 ROC area: 0.800
# Bootstrap #940 ROC area: 0.556
# Bootstrap #941 ROC area: 0.800
# Bootstrap #942 ROC area: 0.950
# Bootstrap #943 ROC area: 0.857
# Bootstrap #944 ROC area: 0.611
# Bootstrap #945 ROC area: 1.000
# Bootstrap #946 ROC area: 0.800
# Bootstrap #947 ROC area: 0.643
# Bootstrap #948 ROC area: 1.000
# Bootstrap #949 ROC area: 0.850
# Bootstrap #950 ROC area: 0.800
# Bootstrap #951 ROC area: 0.700
# Bootstrap #952 ROC area: 0.850
# Bootstrap #953 ROC area: 1.000
# Bootstrap #954 ROC area: 0.800
# Bootstrap #955 ROC area: 0.722
# Bootstrap #956 ROC area: 0.600
# Bootstrap #957 ROC area: 0.778
# Bootstrap #958 ROC area: 0.950
# Bootstrap #959 ROC area: 0.900
# Bootstrap #960 ROC area: 0.778
# Bootstrap #961 ROC area: 1.000
# Bootstrap #962 ROC area: 0.850
# Bootstrap #964 ROC area: 1.000
# Bootstrap #965 ROC area: 0.800
# Bootstrap #966 ROC area: 0.667
# Bootstrap #967 ROC area: 0.800
# Bootstrap #968 ROC area: 0.929
# Bootstrap #969 ROC area: 0.800
# Bootstrap #970 ROC area: 0.857
# Bootstrap #971 ROC area: 0.700
# Bootstrap #972 ROC area: 0.444
# Bootstrap #973 ROC area: 0.889
# Bootstrap #974 ROC area: 0.700
# Bootstrap #975 ROC area: 1.000
# Bootstrap #976 ROC area: 0.800
# Bootstrap #977 ROC area: 0.833
# Bootstrap #978 ROC area: 0.850
# Bootstrap #979 ROC area: 0.667
# Bootstrap #980 ROC area: 0.850
# Bootstrap #981 ROC area: 0.850
# Bootstrap #982 ROC area: 0.667
# Bootstrap #983 ROC area: 0.850
# Bootstrap #984 ROC area: 0.450
# Bootstrap #985 ROC area: 0.700
# Bootstrap #986 ROC area: 1.000
# Bootstrap #987 ROC area: 0.722
# Bootstrap #988 ROC area: 0.929
# Bootstrap #989 ROC area: 1.000
# Bootstrap #990 ROC area: 0.750
# Bootstrap #991 ROC area: 0.714
# Bootstrap #992 ROC area: 0.850
# Bootstrap #993 ROC area: 0.700
# Bootstrap #994 ROC area: 0.929
# Bootstrap #995 ROC area: 0.500
# Bootstrap #996 ROC area: 1.000
# Bootstrap #997 ROC area: 1.000
# Bootstrap #998 ROC area: 1.000
# Bootstrap #999 ROC area: 1.000
# Bootstrap #1000 ROC area: 0.286

# %%
import matplotlib.pyplot as plt
plt.hist(bootstrapped_scores, bins=50)
plt.title('Histogram of the bootstrapped ROC AUC scores')
plt.show()

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 90% confidence interval
# You can change the bounds percentiles to 0.025 and 0.975 to get
# a 95% confidence interval instead.
confidence_lower = sorted_scores[int(0.05 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.95 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score: [0.444 - 1.0]
