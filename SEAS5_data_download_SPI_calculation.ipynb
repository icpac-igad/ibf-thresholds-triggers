# %%
https://cds.climate.copernicus.eu/cdsapp#!/dataset/seasonal-monthly-single-levels?tab=form

# %%
import cfgrib
import xarray as xr


# Import data
grib_data = cfgrib.open_datasets('/home/1993_6l/adaptor.mars.external-1678459523.777364-24930-10-ad353a09-d775-4690-84e6-7605d72b6c84.grib')

# %%
grib_data
# Out:
# [<xarray.Dataset>
#  Dimensions:     (number: 51, time: 358, step: 4, latitude: 7, longitude: 7)
#  Coordinates:
#    * number      (number) int64 0 1 2 3 4 5 6 7 8 ... 42 43 44 45 46 47 48 49 50
#    * time        (time) datetime64[ns] 1993-01-01 1993-02-01 ... 2022-10-01
#    * step        (step) timedelta64[ns] 181 days 182 days 183 days 184 days
#      surface     float64 0.0
#    * latitude    (latitude) float64 4.2 3.2 2.2 1.2 0.2 -0.8 -1.8
#    * longitude   (longitude) float64 29.0 30.0 31.0 32.0 33.0 34.0 35.0
#      valid_time  (time, step) datetime64[ns] ...
#  Data variables:
#      tprate      (number, time, step, latitude, longitude) float32 ...
#  Attributes:
#      GRIB_edition:            1
#      GRIB_centre:             ecmf
#      GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#      GRIB_subCentre:          0
#      Conventions:             CF-1.7
#      institution:             European Centre for Medium-Range Weather Forecasts]

# %%
aa=grib_data[0]['tprate'][50]
aa
# Out:
# <xarray.DataArray 'tprate' (time: 358, step: 4, latitude: 7, longitude: 7)>
# array([[[[nan, ..., nan],
#          ...,
#          [nan, ..., nan]],
#
#         ...,
#
#         [[nan, ..., nan],
#          ...,
#          [nan, ..., nan]]],
#
#
#        ...,
#
#
#        [[[nan, ..., nan],
#          ...,
#          [nan, ..., nan]],
#
#         ...,
#
#         [[nan, ..., nan],
#          ...,
#          [nan, ..., nan]]]], dtype=float32)
# Coordinates:
#     number      int64 50
#   * time        (time) datetime64[ns] 1993-01-01 1993-02-01 ... 2022-10-01
#   * step        (step) timedelta64[ns] 181 days 182 days 183 days 184 days
#     surface     float64 0.0
#   * latitude    (latitude) float64 4.2 3.2 2.2 1.2 0.2 -0.8 -1.8
#   * longitude   (longitude) float64 29.0 30.0 31.0 32.0 33.0 34.0 35.0
#     valid_time  (time, step) datetime64[ns] ...
# Attributes: (12/30)
#     GRIB_paramId:                             172228
#     GRIB_dataType:                            fcmean
# ...

# %%
aa[10]['valid_time']
# Out:
# <xarray.DataArray 'valid_time' (step: 4)>
# array(['1994-05-01T00:00:00.000000000', '1994-05-02T00:00:00.000000000',
#        '1994-05-03T00:00:00.000000000', '1994-05-04T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     number      int64 0
#     time        datetime64[ns] 1993-11-01
#   * step        (step) timedelta64[ns] 181 days 182 days 183 days 184 days
#     surface     float64 0.0
#     valid_time  (step) datetime64[ns] 1994-05-01 1994-05-02 ... 1994-05-04
# Attributes:
#     standard_name:  time
#     long_name:      time

# %%
181/30
# Out:
# 6.033333333333333

# %%
358/12
# Out:
# 29.833333333333332

# %%
2023-1993
# Out:
# 30

# %%
import numpy as np
import verif.data
import verif.input
import verif.interval
import verif.metric

# Set up random forecasts and observations
obs = np.random.randn(100,20,5)
fcst = obs + np.random.randn(100,20,5)*0.2 + 0.3

metric = verif.metric.Mae()
score = metric.compute_from_obs_fcst(obs, fcst)
print(score)
# Out:
# 0.3098514401529407

# %%
metric = verif.metric.Far()
score = metric.compute_from_obs_fcst(obs, fcst)
print(score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6537/3348760945.py in <module>
#       1 metric = verif.metric.Far()
# ----> 2 score = metric.compute_from_obs_fcst(obs, fcst)
#       3 print(score)
#
# TypeError: compute_from_obs_fcst() missing 1 required positional argument: 'interval'
